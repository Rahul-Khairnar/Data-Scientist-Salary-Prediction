# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahul-Khairnar/Data-Scientist-Salary-Prediction/blob/master/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("deep_clean_data.csv")

# %%
df.head()
# Out:
#                    Job Title  ... No. of Competitors
# 0             Data Scientist  ...                  0
# 1  Healthcare Data Scientist  ...                  0
# 2             Data Scientist  ...                  0
# 3             Data Scientist  ...                  3
# 4             Data Scientist  ...                  3
#
# [5 rows x 32 columns]

# %%
df.describe()
# Out:
#            Rating      Founded  ...  Job_Description_Length  No. of Competitors
# count  742.000000   742.000000  ...              742.000000          742.000000
# mean     3.618868  1837.154987  ...             3910.172507            1.053908
# std      0.801210   497.183763  ...             1533.827777            1.384239
# min     -1.000000    -1.000000  ...              407.000000            0.000000
# 25%      3.300000  1939.000000  ...             2834.000000            0.000000
# 50%      3.700000  1988.000000  ...             3781.500000            0.000000
# 75%      4.000000  2007.000000  ...             4772.000000            3.000000
# max      5.000000  2019.000000  ...            10146.000000            4.000000
#
# [8 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Per_Hour', 'Employer_provided', 'min_salary', 'max_salary',
#        'Avg_salary', 'Age_of_company', 'State', 'City', 'job_loc', 'Python',
#        'R_Studio', 'AWS', 'SPARK', 'EXCEL', 'Job_Titles_Simplified',
#        'Title_Seniority', 'Job_Description_Length', 'No. of Competitors'],
#       dtype='object')

# %%
df["Rating"].hist()

# %%
df["Avg_salary"].hist()

# %%
df["Age_of_company"].value_counts().hist()

# %%
df["Job_Description_Length"].hist()

# %%
df.boxplot(column = ["Age_of_company","Avg_salary"])

# %%
df.boxplot(column = ["Rating"])

# %%
df_corr = (df[["Age_of_company","Avg_salary","Rating","Job_Description_Length","No. of Competitors"]]).corr()

# %%
cmap = sns.diverging_palette(220,2,as_cmap = True)
map = sns.heatmap(df_corr, linewidth = 1.0,cmap = cmap)
plt.title("Heat Map")
plt.show()

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Per_Hour', 'Employer_provided', 'min_salary', 'max_salary',
#        'Avg_salary', 'Age_of_company', 'State', 'City', 'job_loc', 'Python',
#        'R_Studio', 'AWS', 'SPARK', 'EXCEL', 'Job_Titles_Simplified',
#        'Title_Seniority', 'Job_Description_Length', 'No. of Competitors'],
#       dtype='object')

# %%
df_categories = df[["Size","Type of ownership","Sector","Revenue"]]

# %%
for i in df_categories:
  category = df_categories[i].value_counts()
  print("Graph for: %s: total: %d" %(i,len(category)))
  chart = sns.barplot(x = category.index,y = category)
  chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
  plt.show()
# Out:
# Graph for: Size: total: 9
# Graph for: Type of ownership: total: 11
# Graph for: Sector: total: 25
# Graph for: Revenue: total: 14

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Per_Hour', 'Employer_provided', 'min_salary', 'max_salary',
#        'Avg_salary', 'Age_of_company', 'State', 'City', 'job_loc', 'Python',
#        'R_Studio', 'AWS', 'SPARK', 'EXCEL', 'Job_Titles_Simplified',
#        'Title_Seniority', 'Job_Description_Length', 'No. of Competitors'],
#       dtype='object')

# %%
df_categories_large = df[["City","Job_Titles_Simplified","Company Name"]]

# %%
for i in df_categories_large:
  category = df_categories_large[i].value_counts()[:20]
  print("Graph for: %s \nTotal values plotted: %d" %(i,len(category)))
  chart = sns.barplot(x = category.index,y = category)
  chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
  plt.show()
# Out:
# Graph for: City
# Total values plotted: 20
# Graph for: Job_Titles_Simplified
# Total values plotted: 7
# Graph for: Company Name
# Total values plotted: 20
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Per_Hour', 'Employer_provided', 'min_salary', 'max_salary',
#        'Avg_salary', 'Age_of_company', 'State', 'City', 'job_loc', 'Python',
#        'R_Studio', 'AWS', 'SPARK', 'EXCEL', 'Job_Titles_Simplified',
#        'Title_Seniority', 'Job_Description_Length', 'No. of Competitors'],
#       dtype='object')

# %%
pd.pivot_table(df,index=['Job_Titles_Simplified','Title_Seniority'],values='Avg_salary')
# Out:
#                                            Avg_salary
# Job_Titles_Simplified     Title_Seniority
# Analyst- Medicine         Not Mentioned     39.800000
# Data Analyst              Junior            53.250000
#                           Not Mentioned     66.540000
#                           Senior            85.871429
# Data Engineer             Not Mentioned     95.597701
#                           Senior           124.689189
# Data Scientist            Junior           106.500000
#                           Not Mentioned    107.043011
#                           Senior           138.956522
# Machine Learning Engineer Not Mentioned    119.133333
#                           Senior           142.071429
# Manager                   Not Mentioned    107.285714
# Other Titles              Not Mentioned     88.912844
#                           Senior           109.112245

# %%
pd.set_option("display.max_rows", None)

# %%
pd.pivot_table(df,index=["State","Job_Titles_Simplified"],values='Avg_salary', aggfunc = "count").sort_values("Avg_salary", ascending = False)
# Out:
#                                  Avg_salary
# State Job_Titles_Simplified
# CA    Data Scientist                     68
# MA    Other Titles                       47
# NY    Data Scientist                     40
# MA    Data Scientist                     30
# CA    Data Analyst                       30
#       Data Engineer                      25
#       Other Titles                       22
# VA    Data Scientist                     18
# WA    Data Scientist                     17
# NY    Data Analyst                       15
# MD    Other Titles                       15
# IL    Data Scientist                     15
# MA    Data Engineer                      13
# TX    Data Scientist                     13
# MD    Data Scientist                     13
# NC    Other Titles                       10
# VA    Data Engineer                      10
# NY    Other Titles                       10
# TN    Data Engineer                      10
# PA    Data Analyst                       10
# ...

# %%
df_pivots = df[['Rating','Industry','Sector','Revenue','Per_Hour','Employer_provided','Age_of_company','Python','R_Studio','AWS','SPARK','EXCEL','Job_Description_Length',"Type of ownership",'Avg_salary']]

# %%
for i in df_pivots:
  if(i != "Avg_salary"):
    print(i)
    print(""*30)
    print(pd.pivot_table(df_pivots,index = i,values = "Avg_salary").sort_values("Avg_salary",ascending = False))
# Out:
# Rating
#
#         Avg_salary
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
#  4.7    103.983871
#  4.3    102.468750
#  3.3    101.858974
#  4.2    100.442308
#  2.2     97.750000
#  4.6     97.250000
#  3.8     96.811475
#  2.1     95.900000
#  3.4     93.011364
#  1.9     87.500000
#  3.1     86.580000
#  3.0     85.588235
#  3.6     85.467391
#  2.8     83.928571
#  2.7     83.250000
#  2.3     81.500000
#  2.9     81.138889
#  4.8     80.277778
#  2.4     60.214286
# Industry
#
#                                           Avg_salary
# Industry
# Other Retail Stores                       163.500000
# Motion Picture Production & Distribution  146.000000
# Financial Analytics & Research            145.125000
# Health, Beauty, & Fitness                 139.500000
# ...

# %%
df_skills = ['Python','R_Studio','AWS','SPARK','EXCEL']
for skills in df_skills:
  print("SKILL: ",skills,"\n")
  print(pd.pivot_table(df, index = "State",columns = skills, values = "Avg_salary"),"\n")
# Out:
# SKILL:  Python
#
# Python           0           1
# State
# AL       53.125000   62.750000
# AZ       85.000000   86.000000
# CA      105.225000  135.440217
# CO       31.000000  103.357143
# CT       71.100000         NaN
# DC       93.571429  139.250000
# DE       27.500000         NaN
# FL       59.100000   86.045455
# GA       80.000000   81.333333
# IA       54.500000  115.500000
# ID       63.500000   49.000000
# IL       79.958333  132.392857
# IN       84.500000   91.750000
# KS             NaN   87.000000
# KY      103.500000   84.000000
# LA       52.250000         NaN
# MA      101.927419  112.865854
# MD       88.565217  114.208333
# MI      101.666667   98.833333
# MN       95.000000   76.000000
# MO       72.500000  109.166667
# NC       94.230769  105.312500
# NE       41.000000         NaN
# NJ       89.437500  118.000000
# NM             NaN   74.333333
# NY       82.000000  106.979167
# OH       74.714286  100.428571
# OR       73.000000   98.500000
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Per_Hour', 'Employer_provided', 'min_salary', 'max_salary',
#        'Avg_salary', 'Age_of_company', 'State', 'City', 'job_loc', 'Python',
#        'R_Studio', 'AWS', 'SPARK', 'EXCEL', 'Job_Titles_Simplified',
#        'Title_Seniority', 'Job_Description_Length', 'No. of Competitors'],
#       dtype='object')

# %%
pd.pivot_table(df,index = "State",columns = "Job_Titles_Simplified",values = "max_salary")
# Out:
# Job_Titles_Simplified  Analyst- Medicine  ...  Other Titles
# State                                     ...
# AL                                   NaN  ...     57.500000
# AZ                                   NaN  ...    166.000000
# CA                                   NaN  ...    131.500000
# CO                             39.000000  ...           NaN
# CT                                   NaN  ...           NaN
# DC                                   NaN  ...           NaN
# DE                                   NaN  ...     34.000000
# FL                                   NaN  ...           NaN
# GA                                   NaN  ...    110.000000
# IA                                   NaN  ...           NaN
# ID                                   NaN  ...           NaN
# IL                                   NaN  ...    175.250000
# IN                                   NaN  ...    148.000000
# KS                                   NaN  ...           NaN
# ...

# %%
pd.pivot_table(df,index = "Type of ownership", columns = "Job_Titles_Simplified", values = "Avg_salary", aggfunc= "count")
# Out:
# Job_Titles_Simplified           Analyst- Medicine  ...  Other Titles
# Type of ownership                                  ...
# -1                                            NaN  ...           1.0
# College / University                          NaN  ...           4.0
# Government                                    1.0  ...           NaN
# Hospital                                      7.0  ...           8.0
# Nonprofit Organization                        4.0  ...          16.0
# Other Organization                            NaN  ...           NaN
# Private                                       1.0  ...          80.0
# Public                                        2.0  ...          40.0
# School / School District                      NaN  ...           NaN
# Subsidiary or Business Segment                NaN  ...           8.0
# Unknown                                       NaN  ...           1.0
#
# [11 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Per_Hour', 'Employer_provided', 'min_salary', 'max_salary',
#        'Avg_salary', 'Age_of_company', 'State', 'City', 'job_loc', 'Python',
#        'R_Studio', 'AWS', 'SPARK', 'EXCEL', 'Job_Titles_Simplified',
#        'Title_Seniority', 'Job_Description_Length', 'No. of Competitors'],
#       dtype='object')

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud,ImageColorGenerator,STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
words = " ".join(df["Job Description"])

def punctuation_stop(text):
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered

word_filtered = punctuation_stop(words)

text = " ".join([ele for ele in word_filtered])

wc = WordCloud(background_color = 'white', random_state = 1, stopwords = STOPWORDS, max_words = 2000, width = 1000, height = 1000)
wc.generate(text)

plt.figure(figsize = [10,10])
plt.imshow(wc,interpolation = "bilinear")
plt.axis('off')
plt.show()
